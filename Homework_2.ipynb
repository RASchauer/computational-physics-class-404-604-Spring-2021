# %% [markdown]
# # Homework
#
# 1)
#
# Write a program to plot
# \begin{equation}
# f(x)=\pi/2+2*[sin(x)+sin(3x)/3+sin(5x)/5+....sin(nx)/n]
# \end{equation}
# from -$\pi$ to $\pi$. Choose n=11, 21 and 31 and plot three curves in one figure. Please use numpy library and matplotlib.
#
# Then setup your github account and commit this to your github.
#
# 2) For graduate student
#
# Write your own Vpython program to generate a simple animation.

# %%
# %matplotlib inline
#matplotlib notebook


import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, pi
# import scipy as sp
# from math import pi
# from mpl_toolkits.mplot3d import Axes3D

# Plot text color, uncomment 'black' for a light background
# COLOR = 'white'
COLOR = 'black'

plt.rcParams['axes.facecolor']= '#373e4b'
plt.rcParams['axes.labelcolor'] = COLOR
# plt.rcParams['axes.prop_cycle'] = cycler(color='bgrcmyk')
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams["figure.figsize"] = (10, 10)
plt.rcParams.update({'font.size': 22})

# %%
def func(x, n):
    m=n
    y=0
    while m >0:
        if m%2==1: # corrected 2/2/2021
            y += sin(m*x)/m
        else:
            pass
        m -= 1
    
    return pi/2 +2*y

# %%
x = np.linspace(-1*pi, pi, 100 )
n = [11, 21, 31]
# print(x)

for ns in n:  
    y = func(x ,ns)
    plt.plot(x,y)

plt.title('Stacked Plots')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)=pi/2+2∗(sin(x)+sin(3x)/3+....sin(nx)/n)\n\nn= [11, 21, 31]')
plt.show()
